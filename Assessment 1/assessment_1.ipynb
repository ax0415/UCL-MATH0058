# %%
wilkinson_coeffs = [ 1,
                  -210,
                 20615,
              -1256850,
              53327946,
           -1672280820,
           40171771630,
         -756111184500,
        11310276995381,
      -135585182899530,
      1307535010540395,
    -10142299865511450,
     63030812099294896,
   -311333643161390640,
   1206647803780373360,
  -3599979517947607200,
   8037811822645051776,
 -12870931245150988800,
  13803759753640704000,
  -8752948036761600000,
   2432902008176640000]

# %%
import numpy as np
import matplotlib.pyplot as plt

eps = 1E-10
wilkinson_coeffs = np.array(wilkinson_coeffs, dtype=np.float64)
perturbed_coeffs = wilkinson_coeffs
perturbed_coeffs[0] *= 1+eps
perturbed_roots = np.roots(perturbed_coeffs)
wilkinson_roots = np.arange(1, 21)
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.plot(np.real(wilkinson_roots), np.imag(wilkinson_roots), 'ro')
ax.plot(np.real(perturbed_roots), np.imag(perturbed_roots), 'bx', markersize=6)
ax.set_xlabel('Real')
ax.set_ylabel('Imaginary')
ax.set_title('Wilkinson polynomial roots')
ax.legend(['Original', 'Perturbed'], loc='lower left')
plt.show()
